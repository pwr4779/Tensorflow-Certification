# %%
import tensorflow as tf
print(tf.__version__)
# Out:
# 2.3.0

# %%
import numpy as np
import matplotlib.pyplot as plt
def plot_series(time, series, format="-", start=0, end=None):
    plt.plot(time[start:end], series[start:end], format)
    plt.xlabel("Time")
    plt.ylabel("Value")
    plt.grid(True)

# %%
import csv
time_step = []
temps = []

with open('daily-min-temperatures.csv') as csvfile:
  reader = csv.reader(csvfile, delimiter=',')
  next(reader)
  step=0
  for row in reader:
    temps.append(float(row[1]))
    time_step.append(step)
    step = step + 1

series = np.array(temps)
time = np.array(time_step)
plt.figure(figsize=(10, 6))
plot_series(time, series)
print(max(temps))
# Out:
# 26.3

# %%
split_time = 2500
time_train = time[:2500]
x_train = series[:2500]
time_valid = time[2500:]
x_valid = series[2500:]

window_size = 30
batch_size = 32
shuffle_buffer_size = 1000

# %%
def windowed_dataset(series, window_size, batch_size, shuffle_buffer):
    series = tf.expand_dims(series, axis=-1)
    ds = tf.data.Dataset.from_tensor_slices(series)
    ds = ds.window(window_size + 1, shift=1, drop_remainder=True)
    ds = ds.flat_map(lambda w: w.batch(window_size + 1))
    ds = ds.shuffle(shuffle_buffer)
    ds = ds.map(lambda w: (w[:-1], w[1:]))
    return ds.batch(batch_size).prefetch(1)

# %%
def model_forecast(model, series, window_size):
    ds = tf.data.Dataset.from_tensor_slices(series)
    ds = ds.window(window_size, shift=1, drop_remainder=True)
    ds = ds.flat_map(lambda w: w.batch(window_size))
    ds = ds.batch(32).prefetch(1)
    forecast = model.predict(ds)
    return forecast

# %%
tf.keras.backend.clear_session()
tf.random.set_seed(51)
np.random.seed(51)
window_size = 64
batch_size = 256
train_set = windowed_dataset(x_train, window_size, batch_size, shuffle_buffer_size)
print(train_set)
print(x_train.shape)

model = tf.keras.models.Sequential([
  tf.keras.layers.Conv1D(filters=32, kernel_size=5,
                      strides=1, padding="causal",
                      activation="relu",
                      input_shape=[None, 1]),
  tf.keras.layers.LSTM(64, return_sequences=True),
  tf.keras.layers.LSTM(64, return_sequences=True),
  tf.keras.layers.Dense(30, activation="relu"),
  tf.keras.layers.Dense(10, activation="relu"),
  tf.keras.layers.Dense(1),
  tf.keras.layers.Lambda(lambda x: x * 30)
])

lr_schedule = tf.keras.callbacks.LearningRateScheduler(
    lambda epoch: 1e-8 * 10**(epoch / 20))
optimizer = tf.keras.optimizers.SGD(lr=1e-8, momentum=0.9)
model.compile(loss=tf.keras.losses.Huber(),
              optimizer=optimizer,
              metrics=["mae"])
history = model.fit(train_set, epochs=100, callbacks=[lr_schedule])
# Out:
# <PrefetchDataset shapes: ((None, None, 1), (None, None, 1)), types: (tf.float64, tf.float64)>
# (2500,)
# Epoch 1/100
# 10/10 [==============================] - 2s 210ms/step - loss: 11.9005 - mae: 12.4002
# Epoch 2/100
# 10/10 [==============================] - 2s 211ms/step - loss: 11.8971 - mae: 12.3968
# Epoch 3/100
# 10/10 [==============================] - 2s 210ms/step - loss: 11.8919 - mae: 12.3917
# Epoch 4/100
# 10/10 [==============================] - 2s 217ms/step - loss: 11.8857 - mae: 12.3854
# Epoch 5/100
# 10/10 [==============================] - 2s 226ms/step - loss: 11.8784 - mae: 12.3782
# Epoch 6/100
# 10/10 [==============================] - 2s 224ms/step - loss: 11.8703 - mae: 12.3700
# Epoch 7/100
# 10/10 [==============================] - 2s 222ms/step - loss: 11.8610 - mae: 12.3607
# Epoch 8/100
# 10/10 [==============================] - 2s 218ms/step - loss: 11.8506 - mae: 12.3503
# Epoch 9/100
# 10/10 [==============================] - 2s 212ms/step - loss: 11.8389 - mae: 12.3386
# Epoch 10/100
# 10/10 [==============================] - 2s 213ms/step - loss: 11.8257 - mae: 12.3253
# Epoch 11/100
# 10/10 [==============================] - 2s 225ms/step - loss: 11.8108 - mae: 12.3104
# Epoch 12/100
# 10/10 [==============================] - 2s 223ms/step - loss: 11.7938 - mae: 12.2935
# Epoch 13/100
# 10/10 [==============================] - 2s 218ms/step - loss: 11.7747 - mae: 12.2743
# Epoch 14/100
# 10/10 [==============================] - 2s 225ms/step - loss: 11.7530 - mae: 12.2526
# Epoch 15/100
# 10/10 [==============================] - 2s 214ms/step - loss: 11.7284 - mae: 12.2280
# Epoch 16/100
# 10/10 [==============================] - 2s 217ms/step - loss: 11.7002 - mae: 12.1998
# Epoch 17/100
# 10/10 [==============================] - 2s 208ms/step - loss: 11.6681 - mae: 12.1676
# Epoch 18/100
# 10/10 [==============================] - 2s 207ms/step - loss: 11.6308 - mae: 12.1303
# Epoch 19/100
# 10/10 [==============================] - 2s 206ms/step - loss: 11.5874 - mae: 12.0869
# Epoch 20/100
# 10/10 [==============================] - 2s 205ms/step - loss: 11.5361 - mae: 12.0355
# Epoch 21/100
# 10/10 [==============================] - 2s 209ms/step - loss: 11.4750 - mae: 11.9744
# Epoch 22/100
# 10/10 [==============================] - 2s 215ms/step - loss: 11.4021 - mae: 11.9014
# Epoch 23/100
# 10/10 [==============================] - 2s 209ms/step - loss: 11.3141 - mae: 11.8133
# Epoch 24/100
# 10/10 [==============================] - 2s 214ms/step - loss: 11.2072 - mae: 11.7064
# Epoch 25/100
# 10/10 [==============================] - 2s 222ms/step - loss: 11.0785 - mae: 11.5777
# Epoch 26/100
# 10/10 [==============================] - 2s 212ms/step - loss: 10.9255 - mae: 11.4246
# Epoch 27/100
# 10/10 [==============================] - 2s 210ms/step - loss: 10.7461 - mae: 11.2452
# Epoch 28/100
# 10/10 [==============================] - 2s 209ms/step - loss: 10.5372 - mae: 11.0361
# Epoch 29/100
# 10/10 [==============================] - 2s 210ms/step - loss: 10.3021 - mae: 10.8008
# Epoch 30/100
# 10/10 [==============================] - 2s 207ms/step - loss: 10.0434 - mae: 10.5418
# Epoch 31/100
# 10/10 [==============================] - 2s 215ms/step - loss: 9.7602 - mae: 10.2586
# Epoch 32/100
# 10/10 [==============================] - 2s 213ms/step - loss: 9.4505 - mae: 9.9489
# Epoch 33/100
# 10/10 [==============================] - 2s 213ms/step - loss: 9.1145 - mae: 9.6128
# Epoch 34/100
# 10/10 [==============================] - 2s 215ms/step - loss: 8.7467 - mae: 9.2448
# Epoch 35/100
# 10/10 [==============================] - 2s 216ms/step - loss: 8.3468 - mae: 8.8441
# Epoch 36/100
# 10/10 [==============================] - 2s 215ms/step - loss: 7.9128 - mae: 8.4093
# Epoch 37/100
# 10/10 [==============================] - 2s 214ms/step - loss: 7.4408 - mae: 7.9364
# Epoch 38/100
# 10/10 [==============================] - 2s 214ms/step - loss: 6.9334 - mae: 7.4282
# Epoch 39/100
# 10/10 [==============================] - 2s 214ms/step - loss: 6.3924 - mae: 6.8858
# Epoch 40/100
# 10/10 [==============================] - 2s 214ms/step - loss: 5.8206 - mae: 6.3112
# Epoch 41/100
# 10/10 [==============================] - 2s 215ms/step - loss: 5.2361 - mae: 5.7229
# Epoch 42/100
# 10/10 [==============================] - 2s 213ms/step - loss: 4.6569 - mae: 5.1392
# Epoch 43/100
# 10/10 [==============================] - 2s 215ms/step - loss: 4.1100 - mae: 4.5888
# Epoch 44/100
# 10/10 [==============================] - 2s 232ms/step - loss: 3.6255 - mae: 4.1018
# Epoch 45/100
# 10/10 [==============================] - 2s 224ms/step - loss: 3.2239 - mae: 3.6943
# Epoch 46/100
# 10/10 [==============================] - 2s 216ms/step - loss: 2.9232 - mae: 3.3881
# Epoch 47/100
# 10/10 [==============================] - 2s 213ms/step - loss: 2.7290 - mae: 3.1914
# Epoch 48/100
# 10/10 [==============================] - 2s 210ms/step - loss: 2.6149 - mae: 3.0762
# Epoch 49/100
# 10/10 [==============================] - 2s 212ms/step - loss: 2.5443 - mae: 3.0048
# Epoch 50/100
# 10/10 [==============================] - 2s 212ms/step - loss: 2.4888 - mae: 2.9478
# Epoch 51/100
# 10/10 [==============================] - 2s 212ms/step - loss: 2.4368 - mae: 2.8944
# Epoch 52/100
# 10/10 [==============================] - 2s 212ms/step - loss: 2.3888 - mae: 2.8452
# Epoch 53/100
# 10/10 [==============================] - 2s 214ms/step - loss: 2.3481 - mae: 2.8038
# Epoch 54/100
# 10/10 [==============================] - 2s 216ms/step - loss: 2.3145 - mae: 2.7696
# Epoch 55/100
# 10/10 [==============================] - 2s 214ms/step - loss: 2.2870 - mae: 2.7420
# Epoch 56/100
# 10/10 [==============================] - 2s 212ms/step - loss: 2.2619 - mae: 2.7169
# Epoch 57/100
# 10/10 [==============================] - 2s 213ms/step - loss: 2.2389 - mae: 2.6940
# Epoch 58/100
# 10/10 [==============================] - 2s 211ms/step - loss: 2.2176 - mae: 2.6728
# Epoch 59/100
# 10/10 [==============================] - 2s 221ms/step - loss: 2.1966 - mae: 2.6519
# Epoch 60/100
# 10/10 [==============================] - 2s 225ms/step - loss: 2.1756 - mae: 2.6307
# Epoch 61/100
# 10/10 [==============================] - 2s 225ms/step - loss: 2.1555 - mae: 2.6105
# Epoch 62/100
# 10/10 [==============================] - 2s 213ms/step - loss: 2.1357 - mae: 2.5906
# Epoch 63/100
# 10/10 [==============================] - 2s 214ms/step - loss: 2.1161 - mae: 2.5709
# Epoch 64/100
# 10/10 [==============================] - 2s 216ms/step - loss: 2.0972 - mae: 2.5518
# Epoch 65/100
# 10/10 [==============================] - 2s 211ms/step - loss: 2.0781 - mae: 2.5325
# Epoch 66/100
# 10/10 [==============================] - 2s 213ms/step - loss: 2.0591 - mae: 2.5134
# Epoch 67/100
# 10/10 [==============================] - 2s 209ms/step - loss: 2.0386 - mae: 2.4931
# Epoch 68/100
# 10/10 [==============================] - 2s 209ms/step - loss: 2.0172 - mae: 2.4719
# Epoch 69/100
# 10/10 [==============================] - 2s 217ms/step - loss: 1.9952 - mae: 2.4499
# Epoch 70/100
# 10/10 [==============================] - 2s 216ms/step - loss: 1.9729 - mae: 2.4274
# Epoch 71/100
# 10/10 [==============================] - 2s 213ms/step - loss: 1.9493 - mae: 2.4033
# Epoch 72/100
# 10/10 [==============================] - 2s 214ms/step - loss: 1.9276 - mae: 2.3811
# Epoch 73/100
# 10/10 [==============================] - 2s 217ms/step - loss: 1.9065 - mae: 2.3595
# Epoch 74/100
# 10/10 [==============================] - 2s 217ms/step - loss: 1.8865 - mae: 2.3390
# Epoch 75/100
# 10/10 [==============================] - 2s 214ms/step - loss: 1.8673 - mae: 2.3196
# Epoch 76/100
# 10/10 [==============================] - 2s 213ms/step - loss: 1.8463 - mae: 2.2983
# Epoch 77/100
# 10/10 [==============================] - 2s 216ms/step - loss: 1.8265 - mae: 2.2780
# Epoch 78/100
# 10/10 [==============================] - 2s 211ms/step - loss: 1.8115 - mae: 2.2635
# Epoch 79/100
# 10/10 [==============================] - 2s 214ms/step - loss: 1.7976 - mae: 2.2494
# Epoch 80/100
# 10/10 [==============================] - 2s 216ms/step - loss: 1.7877 - mae: 2.2389
# Epoch 81/100
# 10/10 [==============================] - 2s 217ms/step - loss: 1.7744 - mae: 2.2255
# Epoch 82/100
# 10/10 [==============================] - 2s 216ms/step - loss: 1.7632 - mae: 2.2138
# Epoch 83/100
# 10/10 [==============================] - 2s 219ms/step - loss: 1.7511 - mae: 2.2013
# Epoch 84/100
# 10/10 [==============================] - 2s 216ms/step - loss: 1.7411 - mae: 2.1912
# Epoch 85/100
# 10/10 [==============================] - 2s 217ms/step - loss: 1.7317 - mae: 2.1812
# Epoch 86/100
# 10/10 [==============================] - 2s 215ms/step - loss: 1.7286 - mae: 2.1782
# Epoch 87/100
# 10/10 [==============================] - 2s 213ms/step - loss: 1.7223 - mae: 2.1716
# Epoch 88/100
# 10/10 [==============================] - 2s 217ms/step - loss: 1.8537 - mae: 2.3072
# Epoch 89/100
# 10/10 [==============================] - 2s 219ms/step - loss: 1.7272 - mae: 2.1765
# Epoch 90/100
# 10/10 [==============================] - 2s 216ms/step - loss: 1.7038 - mae: 2.1521
# Epoch 91/100
# 10/10 [==============================] - 2s 215ms/step - loss: 1.8197 - mae: 2.2725
# Epoch 92/100
# 10/10 [==============================] - 2s 216ms/step - loss: 1.7785 - mae: 2.2289
# Epoch 93/100
# 10/10 [==============================] - 2s 219ms/step - loss: 1.7191 - mae: 2.1677
# Epoch 94/100
# 10/10 [==============================] - 2s 218ms/step - loss: 1.7711 - mae: 2.2213
# Epoch 95/100
# 10/10 [==============================] - 2s 217ms/step - loss: 1.7063 - mae: 2.1549
# Epoch 96/100
# 10/10 [==============================] - 2s 215ms/step - loss: 1.8748 - mae: 2.3277
# Epoch 97/100
# 10/10 [==============================] - 2s 215ms/step - loss: 1.7714 - mae: 2.2214
# Epoch 98/100
# 10/10 [==============================] - 2s 215ms/step - loss: 2.0229 - mae: 2.4807
# Epoch 99/100
# 10/10 [==============================] - 2s 213ms/step - loss: 1.8976 - mae: 2.3519
# Epoch 100/100
# 10/10 [==============================] - 2s 215ms/step - loss: 1.8269 - mae: 2.2797

# %%
plt.semilogx(history.history["lr"], history.history["loss"])
plt.axis([1e-8, 1e-4, 0, 60])
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-27-e83e1469efdf> in <module>
# ----> 1 plt.semilogx(history.history["lr"], history.history["loss"])
#       2 plt.axis([1e-8, 1e-4, 0, 60])
#
# KeyError: 'lr'

# %%
tf.keras.backend.clear_session()
tf.random.set_seed(51)
np.random.seed(51)
window_size = 64
batch_size = 256
train_set = windowed_dataset(x_train, window_size, batch_size, shuffle_buffer_size)
print(train_set)
print(x_train.shape)

model = tf.keras.models.Sequential([
  tf.keras.layers.Conv1D(filters=32, kernel_size=5,
                      strides=1, padding="causal",
                      activation="relu",
                      input_shape=[None, 1]),
  tf.keras.layers.Bidirectional(tf.keras.layers.LSTM(64, return_sequences=True)),
  tf.keras.layers.Bidirectional(tf.keras.layers.LSTM(64, return_sequences=True)),
  tf.keras.layers.Dense(30, activation="relu"),
  tf.keras.layers.Dense(10, activation="relu"),
  tf.keras.layers.Dense(1),
  tf.keras.layers.Lambda(lambda x: x * 30)
])

optimizer = tf.keras.optimizers.SGD(lr=1e-5, momentum=0.9)
model.compile(loss=tf.keras.losses.Huber(),
              optimizer=optimizer,
              metrics=["mae"])
history = model.fit(train_set, epochs=150)
# Out:
# <PrefetchDataset shapes: ((None, None, 1), (None, None, 1)), types: (tf.float64, tf.float64)>
# (2500,)
# Epoch 1/150
# 10/10 [==============================] - 5s 523ms/step - loss: 6.2347 - mae: 6.7253
# Epoch 2/150
# 10/10 [==============================] - 5s 522ms/step - loss: 2.8434 - mae: 3.3102
# Epoch 3/150
# 10/10 [==============================] - 5s 539ms/step - loss: 2.6668 - mae: 3.1340
# Epoch 4/150
# 10/10 [==============================] - 6s 550ms/step - loss: 2.3794 - mae: 2.8387
# Epoch 5/150
# 10/10 [==============================] - 6s 556ms/step - loss: 2.2164 - mae: 2.6725
# Epoch 6/150
# 10/10 [==============================] - 5s 545ms/step - loss: 2.0366 - mae: 2.4901
# Epoch 7/150
# 10/10 [==============================] - 5s 548ms/step - loss: 1.9258 - mae: 2.3753
# Epoch 8/150
# 10/10 [==============================] - 6s 559ms/step - loss: 1.8626 - mae: 2.3117
# Epoch 9/150
# 10/10 [==============================] - 5s 550ms/step - loss: 1.8135 - mae: 2.2621
# Epoch 10/150
# 10/10 [==============================] - 6s 560ms/step - loss: 1.7764 - mae: 2.2251
# Epoch 11/150
# 10/10 [==============================] - 7s 723ms/step - loss: 1.7432 - mae: 2.1918
# Epoch 12/150
# 10/10 [==============================] - 7s 725ms/step - loss: 1.7160 - mae: 2.1645
# Epoch 13/150
# 10/10 [==============================] - 7s 732ms/step - loss: 1.6915 - mae: 2.1396
# Epoch 14/150
# 10/10 [==============================] - 7s 748ms/step - loss: 1.6696 - mae: 2.1172
# Epoch 15/150
# 10/10 [==============================] - 7s 739ms/step - loss: 1.6499 - mae: 2.0971
# Epoch 16/150
# 10/10 [==============================] - 7s 743ms/step - loss: 1.6317 - mae: 2.0785
# Epoch 17/150
# 10/10 [==============================] - 7s 735ms/step - loss: 1.6149 - mae: 2.0614
# Epoch 18/150
# 10/10 [==============================] - 8s 755ms/step - loss: 1.5993 - mae: 2.0455
# Epoch 19/150
# 10/10 [==============================] - 7s 745ms/step - loss: 1.5846 - mae: 2.0305
# Epoch 20/150
# 10/10 [==============================] - 8s 751ms/step - loss: 1.5709 - mae: 2.0166
# Epoch 21/150
# 10/10 [==============================] - 7s 745ms/step - loss: 1.5581 - mae: 2.0034
# Epoch 22/150
# 10/10 [==============================] - 7s 744ms/step - loss: 1.5458 - mae: 1.9909
# Epoch 23/150
# 10/10 [==============================] - 8s 755ms/step - loss: 1.5343 - mae: 1.9790
# Epoch 24/150
# 10/10 [==============================] - 8s 754ms/step - loss: 1.5234 - mae: 1.9679
# Epoch 25/150
# 10/10 [==============================] - 8s 751ms/step - loss: 1.5131 - mae: 1.9572
# Epoch 26/150
# 10/10 [==============================] - 8s 755ms/step - loss: 1.5034 - mae: 1.9470
# Epoch 27/150
# 10/10 [==============================] - 8s 763ms/step - loss: 1.4942 - mae: 1.9375
# Epoch 28/150
# 10/10 [==============================] - 8s 763ms/step - loss: 1.4855 - mae: 1.9283
# Epoch 29/150
# 10/10 [==============================] - 8s 762ms/step - loss: 1.4772 - mae: 1.9196
# Epoch 30/150
# 10/10 [==============================] - 8s 767ms/step - loss: 1.4693 - mae: 1.9114
# Epoch 31/150
# 10/10 [==============================] - 8s 760ms/step - loss: 1.4618 - mae: 1.9035
# Epoch 32/150
# 10/10 [==============================] - 8s 759ms/step - loss: 1.4545 - mae: 1.8959
# Epoch 33/150
# 10/10 [==============================] - 8s 764ms/step - loss: 1.4475 - mae: 1.8888
# Epoch 34/150
# 10/10 [==============================] - 8s 774ms/step - loss: 1.4408 - mae: 1.8818
# Epoch 35/150
# 10/10 [==============================] - 8s 765ms/step - loss: 1.4345 - mae: 1.8752
# Epoch 36/150
# 10/10 [==============================] - 8s 768ms/step - loss: 1.4282 - mae: 1.8689
# Epoch 37/150
# 10/10 [==============================] - 8s 762ms/step - loss: 1.4223 - mae: 1.8627
# Epoch 38/150
# 10/10 [==============================] - 8s 781ms/step - loss: 1.4165 - mae: 1.8568
# Epoch 39/150
# 10/10 [==============================] - 8s 776ms/step - loss: 1.4110 - mae: 1.8511
# Epoch 40/150
# 10/10 [==============================] - 8s 781ms/step - loss: 1.4057 - mae: 1.8456
# Epoch 41/150
# 10/10 [==============================] - 8s 767ms/step - loss: 1.4004 - mae: 1.8402
# Epoch 42/150
# 10/10 [==============================] - 8s 774ms/step - loss: 1.3954 - mae: 1.8351
# Epoch 43/150
# 10/10 [==============================] - 8s 775ms/step - loss: 1.3906 - mae: 1.8301
# Epoch 44/150
# 10/10 [==============================] - 8s 770ms/step - loss: 1.3859 - mae: 1.8252
# Epoch 45/150
# 10/10 [==============================] - 8s 773ms/step - loss: 1.3814 - mae: 1.8205
# Epoch 46/150
# 10/10 [==============================] - 8s 772ms/step - loss: 1.3771 - mae: 1.8160
# Epoch 47/150
# 10/10 [==============================] - 8s 763ms/step - loss: 1.3728 - mae: 1.8116
# Epoch 48/150
# 10/10 [==============================] - 8s 761ms/step - loss: 1.3687 - mae: 1.8073
# Epoch 49/150
# 10/10 [==============================] - 8s 768ms/step - loss: 1.3647 - mae: 1.8031
# Epoch 50/150
# 10/10 [==============================] - 8s 771ms/step - loss: 1.3609 - mae: 1.7992
# Epoch 51/150
# 10/10 [==============================] - 8s 768ms/step - loss: 1.3572 - mae: 1.7952
# Epoch 52/150
# 10/10 [==============================] - 8s 781ms/step - loss: 1.3535 - mae: 1.7914
# Epoch 53/150
# 10/10 [==============================] - 8s 770ms/step - loss: 1.3500 - mae: 1.7876
# Epoch 54/150
# 10/10 [==============================] - 8s 782ms/step - loss: 1.3465 - mae: 1.7841
# Epoch 55/150
# 10/10 [==============================] - 8s 775ms/step - loss: 1.3432 - mae: 1.7805
# Epoch 56/150
# 10/10 [==============================] - 8s 775ms/step - loss: 1.3399 - mae: 1.7771
# Epoch 57/150
# 10/10 [==============================] - 8s 786ms/step - loss: 1.3367 - mae: 1.7737
# Epoch 58/150
# 10/10 [==============================] - 8s 761ms/step - loss: 1.3336 - mae: 1.7704
# Epoch 59/150
# 10/10 [==============================] - 8s 768ms/step - loss: 1.3306 - mae: 1.7673
# Epoch 60/150
# 10/10 [==============================] - 8s 761ms/step - loss: 1.3275 - mae: 1.7641
# Epoch 61/150
# 10/10 [==============================] - 8s 773ms/step - loss: 1.3247 - mae: 1.7610
# Epoch 62/150
# 10/10 [==============================] - 8s 792ms/step - loss: 1.3218 - mae: 1.7580
# Epoch 63/150
# 10/10 [==============================] - 8s 782ms/step - loss: 1.3190 - mae: 1.7551
# Epoch 64/150
# 10/10 [==============================] - 8s 771ms/step - loss: 1.3163 - mae: 1.7522
# Epoch 65/150
# 10/10 [==============================] - 8s 773ms/step - loss: 1.3137 - mae: 1.7494
# Epoch 66/150
# 10/10 [==============================] - 8s 767ms/step - loss: 1.3111 - mae: 1.7467
# Epoch 67/150
# 10/10 [==============================] - 8s 776ms/step - loss: 1.3085 - mae: 1.7441
# Epoch 68/150
# 10/10 [==============================] - 8s 773ms/step - loss: 1.3060 - mae: 1.7414
# Epoch 69/150
# 10/10 [==============================] - 8s 783ms/step - loss: 1.3035 - mae: 1.7388
# Epoch 70/150
# 10/10 [==============================] - 8s 789ms/step - loss: 1.3012 - mae: 1.7363
# Epoch 71/150
# 10/10 [==============================] - 8s 778ms/step - loss: 1.2988 - mae: 1.7338
# Epoch 72/150
# 10/10 [==============================] - 8s 786ms/step - loss: 1.2965 - mae: 1.7314
# Epoch 73/150
# 10/10 [==============================] - 8s 776ms/step - loss: 1.2942 - mae: 1.7289
# Epoch 74/150
# 10/10 [==============================] - 8s 782ms/step - loss: 1.2919 - mae: 1.7266
# Epoch 75/150
# 10/10 [==============================] - 8s 775ms/step - loss: 1.2897 - mae: 1.7243
# Epoch 76/150
# 10/10 [==============================] - 8s 776ms/step - loss: 1.2875 - mae: 1.7220
# Epoch 77/150
# 10/10 [==============================] - 8s 768ms/step - loss: 1.2854 - mae: 1.7198
# Epoch 78/150
# 10/10 [==============================] - 8s 768ms/step - loss: 1.2833 - mae: 1.7176
# Epoch 79/150
# 10/10 [==============================] - 8s 773ms/step - loss: 1.2812 - mae: 1.7154
# Epoch 80/150
# 10/10 [==============================] - 8s 780ms/step - loss: 1.2792 - mae: 1.7133
# Epoch 81/150
# 10/10 [==============================] - 8s 773ms/step - loss: 1.2771 - mae: 1.7112
# Epoch 82/150
# 10/10 [==============================] - 8s 779ms/step - loss: 1.2752 - mae: 1.7091
# Epoch 83/150
# 10/10 [==============================] - 8s 782ms/step - loss: 1.2732 - mae: 1.7070
# Epoch 84/150
# 10/10 [==============================] - 8s 801ms/step - loss: 1.2712 - mae: 1.7051
# Epoch 85/150
# 10/10 [==============================] - 8s 790ms/step - loss: 1.2693 - mae: 1.7030
# Epoch 86/150
# 10/10 [==============================] - 8s 794ms/step - loss: 1.2674 - mae: 1.7010
# Epoch 87/150
# 10/10 [==============================] - 8s 783ms/step - loss: 1.2656 - mae: 1.6993
# Epoch 88/150
# 10/10 [==============================] - 8s 810ms/step - loss: 1.2637 - mae: 1.6973
# Epoch 89/150
# 10/10 [==============================] - 8s 819ms/step - loss: 1.2618 - mae: 1.6953
# Epoch 90/150
# 10/10 [==============================] - 9s 856ms/step - loss: 1.2600 - mae: 1.6935
# Epoch 91/150
# 10/10 [==============================] - 8s 805ms/step - loss: 1.2582 - mae: 1.6916
# Epoch 92/150
# 10/10 [==============================] - 9s 857ms/step - loss: 1.2564 - mae: 1.6898
# Epoch 93/150
# 10/10 [==============================] - 8s 817ms/step - loss: 1.2547 - mae: 1.6880
# Epoch 94/150
# 10/10 [==============================] - 8s 843ms/step - loss: 1.2530 - mae: 1.6862
# Epoch 95/150
# 10/10 [==============================] - 8s 788ms/step - loss: 1.2512 - mae: 1.6844
# Epoch 96/150
# 10/10 [==============================] - 8s 782ms/step - loss: 1.2495 - mae: 1.6827
# Epoch 97/150
# 10/10 [==============================] - 8s 806ms/step - loss: 1.2478 - mae: 1.6809
# Epoch 98/150
# 10/10 [==============================] - 8s 811ms/step - loss: 1.2462 - mae: 1.6793
# Epoch 99/150
# 10/10 [==============================] - 8s 828ms/step - loss: 1.2445 - mae: 1.6775
# Epoch 100/150
# 10/10 [==============================] - 8s 780ms/step - loss: 1.2429 - mae: 1.6759
# Epoch 101/150
# 10/10 [==============================] - 8s 807ms/step - loss: 1.2413 - mae: 1.6742
# Epoch 102/150
# 10/10 [==============================] - 8s 831ms/step - loss: 1.2397 - mae: 1.6726
# Epoch 103/150
# 10/10 [==============================] - 9s 858ms/step - loss: 1.2381 - mae: 1.6710
# Epoch 104/150
# 10/10 [==============================] - 8s 806ms/step - loss: 1.2365 - mae: 1.6693
# Epoch 105/150
# 10/10 [==============================] - 8s 779ms/step - loss: 1.2349 - mae: 1.6677
# Epoch 106/150
# 10/10 [==============================] - 8s 796ms/step - loss: 1.2334 - mae: 1.6662
# Epoch 107/150
# 10/10 [==============================] - 8s 789ms/step - loss: 1.2318 - mae: 1.6646
# Epoch 108/150
# 10/10 [==============================] - 8s 819ms/step - loss: 1.2303 - mae: 1.6630
# Epoch 109/150
# 10/10 [==============================] - 8s 830ms/step - loss: 1.2288 - mae: 1.6615
# Epoch 110/150
# 10/10 [==============================] - 8s 824ms/step - loss: 1.2273 - mae: 1.6600
# Epoch 111/150
# 10/10 [==============================] - 8s 821ms/step - loss: 1.2258 - mae: 1.6585
# Epoch 112/150
# 10/10 [==============================] - 8s 809ms/step - loss: 1.2244 - mae: 1.6570
# Epoch 113/150
# 10/10 [==============================] - 8s 788ms/step - loss: 1.2229 - mae: 1.6555
# Epoch 114/150
# 10/10 [==============================] - 8s 812ms/step - loss: 1.2215 - mae: 1.6540
# Epoch 115/150
# 10/10 [==============================] - 8s 824ms/step - loss: 1.2201 - mae: 1.6526
# Epoch 116/150
# 10/10 [==============================] - 8s 811ms/step - loss: 1.2187 - mae: 1.6511
# Epoch 117/150
# 10/10 [==============================] - 8s 832ms/step - loss: 1.2173 - mae: 1.6496
# Epoch 118/150
# 10/10 [==============================] - 8s 797ms/step - loss: 1.2159 - mae: 1.6483
# Epoch 119/150
# 10/10 [==============================] - 8s 776ms/step - loss: 1.2145 - mae: 1.6468
# Epoch 120/150
# 10/10 [==============================] - 8s 797ms/step - loss: 1.2132 - mae: 1.6454
# Epoch 121/150
# 10/10 [==============================] - 8s 781ms/step - loss: 1.2118 - mae: 1.6440
# Epoch 122/150
# 10/10 [==============================] - 8s 780ms/step - loss: 1.2105 - mae: 1.6427
# Epoch 123/150
# 10/10 [==============================] - 8s 788ms/step - loss: 1.2091 - mae: 1.6412
# Epoch 124/150
# 10/10 [==============================] - 8s 791ms/step - loss: 1.2078 - mae: 1.6399
# Epoch 125/150
# 10/10 [==============================] - 8s 796ms/step - loss: 1.2065 - mae: 1.6385
# Epoch 126/150
# 10/10 [==============================] - 11s 1s/step - loss: 1.2052 - mae: 1.6371
# Epoch 127/150
# 10/10 [==============================] - 12s 1s/step - loss: 1.2039 - mae: 1.6358
# Epoch 128/150
# 10/10 [==============================] - 8s 784ms/step - loss: 1.2027 - mae: 1.6345
# Epoch 129/150
# 10/10 [==============================] - 8s 780ms/step - loss: 1.2014 - mae: 1.6331
# Epoch 130/150
# 10/10 [==============================] - 8s 785ms/step - loss: 1.2001 - mae: 1.6318
# Epoch 131/150
# 10/10 [==============================] - 8s 790ms/step - loss: 1.1989 - mae: 1.6304
# Epoch 132/150
# 10/10 [==============================] - 8s 784ms/step - loss: 1.1977 - mae: 1.6292
# Epoch 133/150
# 10/10 [==============================] - 8s 786ms/step - loss: 1.1964 - mae: 1.6278
# Epoch 134/150
# 10/10 [==============================] - 8s 790ms/step - loss: 1.1952 - mae: 1.6266
# Epoch 135/150
# 10/10 [==============================] - 8s 801ms/step - loss: 1.1940 - mae: 1.6253
# Epoch 136/150
# 10/10 [==============================] - 8s 785ms/step - loss: 1.1928 - mae: 1.6240
# Epoch 137/150
# 10/10 [==============================] - 8s 783ms/step - loss: 1.1916 - mae: 1.6227
# Epoch 138/150
# 10/10 [==============================] - 8s 782ms/step - loss: 1.1904 - mae: 1.6215
# Epoch 139/150
# 10/10 [==============================] - 8s 777ms/step - loss: 1.1892 - mae: 1.6202
# Epoch 140/150
# 10/10 [==============================] - 8s 772ms/step - loss: 1.1880 - mae: 1.6190
# Epoch 141/150
# 10/10 [==============================] - 8s 785ms/step - loss: 1.1868 - mae: 1.6177
# Epoch 142/150
# 10/10 [==============================] - 8s 784ms/step - loss: 1.1857 - mae: 1.6165
# Epoch 143/150
# 10/10 [==============================] - 8s 783ms/step - loss: 1.1845 - mae: 1.6153
# Epoch 144/150
# 10/10 [==============================] - 8s 788ms/step - loss: 1.1834 - mae: 1.6141
# Epoch 145/150
# 10/10 [==============================] - 8s 775ms/step - loss: 1.1822 - mae: 1.6128
# Epoch 146/150
# 10/10 [==============================] - 8s 784ms/step - loss: 1.1811 - mae: 1.6117
# Epoch 147/150
# 10/10 [==============================] - 8s 770ms/step - loss: 1.1799 - mae: 1.6104
# Epoch 148/150
# 10/10 [==============================] - 8s 775ms/step - loss: 1.1788 - mae: 1.6093
# Epoch 149/150
# 10/10 [==============================] - 8s 772ms/step - loss: 1.1777 - mae: 1.6081
# Epoch 150/150
# 10/10 [==============================] - 8s 773ms/step - loss: 1.1766 - mae: 1.6069

# %%
rnn_forecast = model_forecast(model, series[..., np.newaxis], window_size)
rnn_forecast = rnn_forecast[split_time - window_size:-1, -1, 0]

plt.figure(figsize=(10, 6))
plot_series(time_valid, x_valid)
plot_series(time_valid, rnn_forecast)

# %%
tf.keras.metrics.mean_absolute_error(x_valid, rnn_forecast).numpy()
# Out:
# 2.9339633
